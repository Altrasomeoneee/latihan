# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
data = [
    [170, 75, "Pemain Bola"],
    [190, 95, "Petinju"],
    [167, 73, "Pemain Bola"],
    [185, 85, "Petinju"],
    [200, 90, "Petinju"],
    [178, 80, "Pemain Bola"],
    [198, 93, "Petinju"]
]

# Create the DataFrame
df = pd.DataFrame(data, columns=["Tinggi", "Berat", "Kelas"])

# %%
df
# Out:
#    Tinggi  Berat        Kelas
# 0     170     75  Pemain Bola
# 1     190     95      Petinju
# 2     167     73  Pemain Bola
# 3     185     85      Petinju
# 4     200     90      Petinju
# 5     178     80  Pemain Bola
# 6     198     93      Petinju

# %%
X = df.drop("Kelas", axis=1)
y = df['Kelas']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.4, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
anak_1 = [180,83]
anak_2 = [187,78]
hasil = knn.predict(X_test)
print(hasil)
print(confusion_matrix(hasil,y_test,labels=['Pemain Bola','Petinju']))
print(accuracy_score(hasil,y_test))
# Out:
# ['Pemain Bola' 'Petinju' 'Petinju']
# [[1 0]
#  [1 1]]
# 0.6666666666666666

# %%
# Clean up the OCR output and create a list of lists for DataFrame creation
data_2 = [
    [170, 77, "Pemain Bola"],
    [195, 95, "Petinju"],
    [167, 75, "Pemain Bola"],
    [185, 85, "Petinju"],
    [205, 92, "Petinju"],
    [179, 80, "Pemain Bola"],
    [175, 93, "Petinju"]
]

# Create the DataFrame
df_2 = pd.DataFrame(data_2, columns=["Tinggi", "Berat", "Kelas"])
df_2
# Out:
#    Tinggi  Berat        Kelas
# 0     170     77  Pemain Bola
# 1     195     95      Petinju
# 2     167     75  Pemain Bola
# 3     185     85      Petinju
# 4     205     92      Petinju
# 5     179     80  Pemain Bola
# 6     175     93      Petinju

# %%
X = df_2.drop("Kelas", axis=1)
y = df_2['Kelas']

# %%
hasil2 = knn.predict(X)

# %%
df_2['Kelas Baru'] = pd.DataFrame(hasil2)

# %%
df_2
# Out:
#    Tinggi  Berat        Kelas   Kelas Baru
# 0     170     77  Pemain Bola  Pemain Bola
# 1     195     95      Petinju      Petinju
# 2     167     75  Pemain Bola  Pemain Bola
# 3     185     85      Petinju      Petinju
# 4     205     92      Petinju      Petinju
# 5     179     80  Pemain Bola      Petinju
# 6     175     93      Petinju      Petinju

# %%
confusion_matrix(hasil2,y,labels=['Pemain Bola','Petinju'])
# Out:
# array([[2, 0],
#        [1, 4]])

# %%
accuracy_score(hasil2,y)
# Out:
# 0.8571428571428571
